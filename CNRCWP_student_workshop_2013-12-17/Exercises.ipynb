# %% [markdown]
# Exercises for Python tutorial
# =======
#
# Syntax and basic constructs
# ------
#
# 1. Write a function called `post_message` with one positional argument (message) and a named argument (author, default should be your name), when `message = "Hello"` and `name = "xxx"` the function should print "xxx says: Hello". Use format method of the builtin string class.
#
# 2. Save the function `post_message` to the file `post_helper.py` and then call this function from another file `do_post.py`
#
# 3. Calculate 20 first fibonacci numbers
#
# 4. Create a class Person and a class Student that inherits from the Person, but has an additional method `get_university` which should return a univerity where a student is studying.
#
#
# Useful builtin modules and classes, data containers
# ----
#
# 1. Create 20 objects of class Person with name and age fields. Put them into a list and print sorted by name, sorted by age
#
# 2. (Problem on dict)
#
# 3. Check if a string is a palindrome
#
# 3. Implement a function that takes a line containing numbers (integers or reals) and words, returns a list of numbers.
#
# 4. Problem with dates (How old are you in days, weeks)
#
# 5. Iterators, groupby
#
#
# NetCDF4
# ---
#
# 1. Write a 3d field into a netcdf file with dimensions (time, longitude, latitude). The field is a random 2D field with the first record corresponding to 2001-01-01 and the last to 2005-01-01. The time step is 12 hours.
#
# 2. Calculate seasonal means from the data created in the previous exercise. (Use groupby function)
#
# 1D and 2D plots
# ------
#
# 1. Plot seasonal mean fields calculated in the previous exercise.
#
# 2.
#
#
# 2D plots of Geographical data using basemap module
# ----
#
# 1. Plot GZ and wind data
# 2. Plot fields over different domains (The files are in the example dataset)
#
# 3. Given coordinates of 2 points on a rotated equator find longitude of a real pole in rotated coordinates and longitude of the rotated pole in real lat/lon coordinate system.
#
# 4. Read a shapefile using basemap and change some colors accoding to shape properties
#
# Interpolation using KDTree
# ----
#
# 1. *TODO:* Have to prepare temperature field from CRU and from the model. Calculate biases in the temperature and make a 2D plot.
#
# 2. Select a region and calculate the biases for the area averaged temperature toevaluate seasonal variation of the biases.
#
# 3. Reading shapefiles usin osgeo.
