# %%
# %matplotlib inline
#%reload_ext mpl_toolkits.basemap
from matplotlib import colors

# %%
from mpl_toolkits.basemap import Basemap
import numpy as np
import matplotlib.pyplot as plt


def valueError():
    m = Basemap(projection='robin',lon_0=115,resolution='c')
    m.drawcoastlines()
    m.fillcontinents(color='sienna',lake_color='aqua')
    m.drawmapboundary(fill_color='lightsteelblue')

    x = [-5.435, -6.660817, -119.2511944, 17.719833]
    y = [36.136, 4.746717, 39.4030278, -14.657583]
    
    
    x, y = list(zip(*sorted(zip(x, y), key=lambda it: it[0])))
    print(x)
    print(y)
    

    m.scatter(x, y,50,marker='o',color='g',latlon=True, zorder=10)
    plt.show()

def works():
    m = Basemap(projection='robin',lon_0=115,resolution='c')
    m.drawcoastlines()
    m.fillcontinents(color='sienna',lake_color='aqua')
    m.drawmapboundary(fill_color='lightsteelblue')
    x = [-5.435, -6.660817, -119.2511944, 17.719833]
    y = [36.136, 4.746717, 39.4030278, -14.657583]

    x,y = m(x,y)
    m.scatter(x, y,50,marker='o',color='g',latlon=False, zorder=10)
    plt.show()

def main():
    works()
    valueError()

if __name__ == '__main__':
    main()
# Out:
# (-119.2511944, -6.660817, -5.435, 17.719833)
# (39.4030278, 4.746717, 36.136, -14.657583)
# londiff =  [ 247.4096226    1.225817    23.154833 ]
# thresh =  336.845167
# itemindex =  []
