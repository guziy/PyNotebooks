# %%
import matplotlib.pyplot as plt
from matplotlib import cm

# %%
N = 10
cmap = cm.get_cmap("jet", N)
colors = [cmap(i/float(N)) for i in range(N)]
for i, c in enumerate(colors):
    plt.plot(range(10), [i+j for j in range(10)], color=c)

# %%
2+1+1.95+2+1.25+1+1
# Out:
# 10.2

# %%
import numpy as np
x = np.arange(0,-16.4, -0.01)

# %%
v1 = np.zeros((len(x),))
v1[x > -3.3] = 0
v1[(-3.3>= x)&(x > -3.5)] = 1
v1[(-3.5>= x)&(x > -4.6)] = 3
v1[(-4.6>= x)&(x > -5.2)] = 4
v1[(-5.2>= x)&(x > -5.7)] = 5
v1[(-5.7>= x)&(x > -6.5)] = 6
v1[(-6.5>= x)&(x > -6.6)] = 7
v1[(-6.6>= x)&(x > -6.8)] = 8
v1[(-6.8>= x)&(x > -7)] = 9
v1[(-7>= x)&(x > -7.3)] = 10
v1[(-7.3>= x)&(x > -7.7)] = 11
v1[(-7.7>= x)&(x > -8.1)] = 12
v1[(-8.1>= x)&(x > -8.5)] = 14
v1[(-8.5>= x)&(x > -9.3)] = 15
v1[(-9.3>= x)&(x > -9.4)] = 16
v1[(-9.4>= x)&(x > -9.5)] = 17
v1[(-9.5>= x)&(x > -9.6)] = 18
v1[(-9.6>= x)&(x > -16.3)] = 19
v1[x <= -16.3] = 20


v2 = np.zeros((len(x),))
v2[x>-1.9] = 0
v2[(-1.9 >= x)&(x > -2.4)] = 1
v2[(-2.4 >= x)&(x > -4.0)] = 7
v2[(-4.0 >= x)&(x > -6.1)] = 9
v2[(-6.1 >= x)&(x > -6.5)] = 12
v2[(-6.5 >= x)&(x > -7)] = 19
v2[x <= -7] = 20




plt.figure(figsize=(8,6))

plt.plot(x, v1, label = u"Distillé", lw = 2)
plt.plot(x, v2, label = u"Pluie sale", lw = 2)

plt.ylabel("$N_{\\rm gouttes}$")
plt.xlabel(u"Température $^\circ{\\rm C }$")
plt.ylim(0,22)
plt.legend()
len(x)
# Out:
# 1640

# %%
x1 = [-3.3,] + [-3.5] * 2 + [-4.6,-5.2,-5.7,-6.5,-6.6,-6.8,-7,-7.3, -7.7,-8.1,-8.1,-8.5,-9.3, -9.4, -9.5, -9.6, -16.3]
print x1
print len(x1), np.mean(x1)
x2 = [-1.9,] + 6*[-2.4]+2*[-4,] + 3 * [-6.1, ] + 7*[-6.5]+[-7]
print len(x2), np.mean(x2)
# Out:
# [-3.3, -3.5, -3.5, -4.6, -5.2, -5.7, -6.5, -6.6, -6.8, -7, -7.3, -7.7, -8.1, -8.1, -8.5, -9.3, -9.4, -9.5, -9.6, -16.3]
# 20 -7.325
# 20 -4.755
