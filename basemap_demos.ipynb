# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap


plt.figure(figsize=(20,10))
m = Basemap(resolution='c',projection='ortho',lat_0=35.,lon_0=-60.)
#m.drawmeridians(np.arange(-180,180, 5))
m.drawparallels(np.arange(0,20, 5))
m.drawcoastlines()
plt.show()

from mpl_toolkits import basemap
print basemap.__version__
# Out:
# 1.0.8

# %%
from mpl_toolkits import basemap

m1 = basemap.Basemap(projection='cea', lon_0=0)
lon = [-135, -45, 45, 135]
lat = [45, 45, 45, 45]
m1.plot(lon, lat, latlon=True)
m1.drawcoastlines()

# %%
lat = [-45, 45, 45, 45, 45, 0.1]
lon = [135, -135, -45, 45, 135, -90]
m1.plot(lon, lat, latlon=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-3d75493453b2> in <module>()
#       1 lat = [-45, 45, 45, 45, 45, 0.1]
#       2 lon = [135, -135, -45, 45, 135, -90]
# ----> 3 m1.plot(lon, lat, latlon=True)
#
# /home/san/Python/virtual_envs/py2.7-default/local/lib/python2.7/site-packages/mpl_toolkits/basemap/__init__.pyc in with_transform(self, x, y, *args, **kwargs)
#     536             if self.projection in _cylproj or self.projection in _pseudocyl:
#     537                 if x.ndim == 1:
# --> 538                     x = self.shiftdata(x)
#     539                 elif x.ndim == 0:
#     540                     if x > 180:
#
# /home/san/Python/virtual_envs/py2.7-default/local/lib/python2.7/site-packages/mpl_toolkits/basemap/__init__.pyc in shiftdata(self, lonsin, datain, lon_0)
#    4793             thresh = 360.-londiff_sort[-2]
# ...
