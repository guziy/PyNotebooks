# %%
# %matplotlib inline
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import os

# %%
plt.figure(figsize=(20, 10))
b = Basemap(llcrnrlon=-130, urcrnrlon=-100, llcrnrlat=35, urcrnrlat=55, resolution="i")
b.drawcoastlines()
lines = b.drawrivers(color="b")
b.readshapefile(os.path.expanduser("/home/san/Downloads/bow_river/bow_projected"), "basins", color="m")
# Out:
# (1,
#  5,
#  [-116.54912393427317, 49.9332415924086, 0.0, 0.0],
#  [-111.00272931905403, 51.72723792578264, 0.0, 0.0],
#  <matplotlib.collections.LineCollection at 0x7fbd4b529128>)

# %%
from shapely.geometry import LineString
for p in lines.get_paths():
    line = LineString(p.vertices)
    print(line.wkt)
# Out:
# LINESTRING (-129 54.38765716552734, -129.1405334472656 54.35858154296875, -129.2369689941406 54.31997680664062, -129.3616333007812 54.30303955078125, -129.4299926757812 54.24749755859375, -129.4677581787109 54.2410888671875)
# LINESTRING (-128.3312683105469 55, -128.3839111328125 54.95697021484375, -128.3797149658203 54.88250732421875, -128.2841949462891 54.81246948242188, -128.2561187744141 54.749755859375, -128.4108428955078 54.6319580078125, -128.4283142089844 54.56946563720703, -128.5417022705078 54.52803802490234, -128.5750427246094 54.49141693115234, -128.6644592285156 54.51308441162109, -128.8497009277344 54.41527557373047, -128.9102783203125 54.39948272705078, -128.9639129638672 54.40779876708984, -129 54.38765716552734)
# LINESTRING (-126.9433135986328 54.09635925292969, -126.8586273193359 54.05363464355469, -126.73388671875 54.04776000976562, -126.5672607421875 54)
# LINESTRING (-125 54.43907928466797, -125.1619720458984 54.49279022216797)
# ...

# %%
p = lines.get_paths()[0]

# %%
p.vertices
