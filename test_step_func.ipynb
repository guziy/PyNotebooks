# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
mask = np.array(range(1000)) // 20

# %%
x = np.random.randn(len(mask))

# %%
plt.plot(x[mask])

# %%
plt.plot(mask)
