# %%
import numpy as np
from scipy.integrate import odeint
from scipy.interpolate import interp1d

t = np.linspace(0, 4, 4)

data = [1, 2, 3, 4]

linear_interpolation = interp1d(t, data)

def func(y, t0):
    print 't0', t0
    return -2*y + linear_interpolation(t0)

soln = odeint(func, 1, t[:-1])
# Out:
# t0 0.0
# t0 0.000135425028933
# t0 0.000135425028933
# t0 0.000270850057866
# t0 0.000270850057866
# t0 0.00314376997574
# t0 0.00314376997574
# t0 0.00601668989362
# t0 0.00601668989362
# t0 0.0088896098115
# t0 0.0088896098115
# t0 0.0203150449729
# t0 0.0203150449729
# t0 0.017715873583
# t0 0.017715873583
# t0 0.0265421373544
# t0 0.0265421373544
# t0 0.0353684011259
# t0 0.0353684011259
# t0 0.0441946648973
# t0 0.0441946648973
# t0 0.0618471924402
# t0 0.0618471924402
# t0 0.0794997199832
# t0 0.0794997199832
# t0 0.0971522475261
# t0 0.0971522475261
# t0 0.114804775069
# t0 0.114804775069
# t0 0.132457302612
# t0 0.132457302612
# t0 0.18818303201
# t0 0.18818303201
# t0 0.243908761407
# t0 0.243908761407
# t0 0.299634490805
# t0 0.299634490805
# t0 0.283867163554
# t0 0.283867163554
# t0 0.323825565702
# t0 0.323825565702
# t0 0.363783967849
# t0 0.363783967849
# t0 0.403742369996
# t0 0.403742369996
# t0 0.443700772143
# t0 0.443700772143
# t0 0.48365917429
# t0 0.48365917429
# t0 0.545024180169
# t0 0.545024180169
# t0 0.606389186048
# t0 0.606389186048
# t0 0.667754191927
# t0 0.667754191927
# t0 0.729119197807
# t0 0.729119197807
# t0 0.790484203686
# t0 0.790484203686
# t0 0.851849209565
# t0 0.851849209565
# t0 0.913214215444
# t0 0.913214215444
# t0 0.998204255068
# t0 0.998204255068
# t0 1.08319429469
# t0 1.08319429469
# t0 1.16818433432
# t0 1.16818433432
# t0 1.25317437394
# t0 1.25317437394
# t0 1.33816441357
# t0 1.33816441357
# t0 1.42315445319
# t0 1.42315445319
# t0 1.50814449282
# t0 1.50814449282
# t0 1.60814449278
# t0 1.60814449278
# t0 1.70814449274
# t0 1.70814449274
# t0 1.80814449269
# t0 1.80814449269
# t0 1.90814449265
# t0 1.90814449265
# t0 2.00814449261
# t0 2.00814449261
# t0 2.10814449257
# t0 2.10814449257
# t0 2.20814449253
# t0 2.20814449253
# t0 2.30814449249
# t0 2.30814449249
# t0 2.42052566821
# t0 2.42052566821
# t0 2.53290684394
# t0 2.53290684394
# t0 2.64528801966
# t0 2.64528801966
# t0 2.75766919538
# t0 2.75766919538

# %%
interp1d??

# %%
odeint??

# %%
soln
# Out:
# array([[ 1.        ],
#        [ 0.86026986],
#        [ 1.31581921]])
