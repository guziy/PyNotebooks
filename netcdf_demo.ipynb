# %%
path = "sresa1b_ncar_ccsm3_0_run1_200001.nc"

# %%
path
# Out:
# 'sresa1b_ncar_ccsm3_0_run1_200001.nc'

# %%
from netCDF4 import Dataset

# %%
ds = Dataset(path)

# %%
ds.variables.keys()
# Out:
# [u'area',
#  u'lat',
#  u'lat_bnds',
#  u'lon',
#  u'lon_bnds',
#  u'msk_rgn',
#  u'plev',
#  u'pr',
#  u'tas',
#  u'time',
#  u'time_bnds',
#  u'ua']

# %%
var = ds.variables["pr"]

# %%
var.shape
# Out:
# (1, 128, 256)

# %%
data = var[0, :, :]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.pcolormesh(data.transpose())
plt.title("My title $x^2$")

# %%
plt.show()
