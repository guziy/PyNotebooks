# %%
import tables as tb
import numpy as np
from datetime import datetime
import time

# %%
###generate the date to field dictionary
from datetime import datetime, timedelta
def generate_date_to_field_dict():
    t0 = datetime.now()
    res = []
    for i in range(400):
        t = t0 + timedelta(days = 1) * i
        res.append( (t.year, t.month, t.day, t.hour, t.minute, t.second, time.mktime(t.timetuple()) , np.random.randn(10,10)) )
    return res
    
data = generate_date_to_field_dict()

# %%
#if h5file.isopen: h5file.close()

#print h5file.isopen

h5file = tb.openFile("tutorial1.h5", mode = "w", title = "Test file")
#h5file.removeNode("year_2013")
#h5file.removeNode("year_2014")



##create groups for different years
#for d, v in data.iteritems():
#    yearGroupName = d.strftime("year_%Y") 
#    if not yearGroupName in h5file.root:
#        h5file.createGroup("/", d.strftime("year_%Y"))
    

    
#delete nodes created for each year
for year in (2013, 2014):
    nodePath = "/" + "year-{0}".format(year)
    if nodePath in h5file:
        h5file.removeNode(nodePath)

    nodePath = "/" + "year_{0}".format(year)
    if nodePath in h5file:
        h5file.removeNode(nodePath)
        
#ceate a table  for a variable random and call it random        
print h5file


#when passing pos make sure to use different variables
class RandomTableDescription(tb.IsDescription):
    year = tb.Int32Col()
    month = tb.Int32Col()
    day = tb.Int32Col()
    hour = tb.Int32Col()
    minute = tb.Int32Col()
    second = tb.Int32Col()
    date = tb.Time32Col()
    field = tb.Float32Col(shape = data[0][-1].shape)


#create random table if it does not exist yet
if "/random" not in h5file:
    print "creating a table: /random"
    randomTable = h5file.createTable("/", "random", RandomTableDescription)
else:
    randomTable = h5file.getNode("/random")

#randomTable.append(data)    

row = randomTable.row

for rowData in data:
    row["year"] = rowData[0]
    row["month"] = rowData[1]
    row["day"] = rowData[2]
    row["hour"] = rowData[3]
    row["minute"] = rowData[4]
    row["second"] = rowData[5]
    row["date"] = rowData[6]
    row["field"] = rowData[-1]
    row.append()
randomTable.flush()


#print data.items()
print h5file

h5file.close()
    
    
##To see the schema of the created file in command line, do:
#huziy$ ptdump-2.7 -v tutorial1.h5
#/ (RootGroup) 'Test file'
#/random (Table(400,)) ''
#  description := {
#  "day": Int32Col(shape=(), dflt=0, pos=0),
#  "field": Float32Col(shape=(10, 10), dflt=0.0, pos=1),
#  "hour": Int32Col(shape=(), dflt=0, pos=2),
#  "minute": Int32Col(shape=(), dflt=0, pos=3),
#  "month": Int32Col(shape=(), dflt=0, pos=4),
#  "second": Int32Col(shape=(), dflt=0, pos=5),
#  "year": Int32Col(shape=(), dflt=0, pos=6)}
#  byteorder := 'little'
#  chunkshape := (154,)
# Out:
# tutorial1.h5 (File) 'Test file'
# Last modif.: 'Thu Jun 13 13:26:24 2013'
# Object Tree:
# / (RootGroup) 'Test file'
#
# creating a table: /random
# tutorial1.h5 (File) 'Test file'
# Last modif.: 'Thu Jun 13 13:26:24 2013'
# Object Tree:
# / (RootGroup) 'Test file'
# /random (Table(400,)) ''

# %%
h5file = tb.openFile("tutorial1.h5")

print h5file

randomTable = h5file.getNode("/random")

##selecting by index
for x in randomTable.iterrows(start = 10, stop = 20):
    print x["year"]
print 20 * "==="
##selecting by condition
##calculate summer mean
all_data = []
for row in randomTable.where("(month >= 6) & (month <= 8)"):
    all_data.append(row["field"])
    

print len(all_data)
print np.mean(all_data, axis = 0)
h5file.close()
# Out:
# tutorial1.h5 (File) 'Test file'
# Last modif.: 'Thu Jun 13 13:24:56 2013'
# Object Tree:
# / (RootGroup) 'Test file'
# /random (Table(400,)) ''
#
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# ============================================================
# 127
# [[ -4.72688265e-02  -8.92316848e-02   1.08056916e-02   2.93166172e-02
#     4.25867252e-02  -8.23869482e-02   4.71907444e-02   3.45011279e-02
#    -1.95032716e-01  -5.67409843e-02]
#  [ -4.65890504e-02   4.95650582e-02  -1.16381822e-02   5.08169457e-02
#     2.00856756e-02  -2.81088110e-02   9.18765515e-02   4.62536290e-02
#     2.08356138e-02  -6.72179908e-02]
#  [ -1.05589181e-01  -1.45985588e-01  -6.08563758e-02   1.61691383e-01
#     5.50654382e-02   8.46172124e-03  -1.65862650e-01   3.38142365e-02
#     2.28780746e-01   4.61498760e-02]
#  [  1.99343041e-01  -4.72827698e-04  -1.30257785e-01  -4.41825874e-02
#    -1.09052114e-01   4.31456976e-02  -5.50114661e-02  -1.34911716e-01
#    -1.20831944e-01  -7.47690871e-02]
#  [  3.50449532e-02  -5.12583070e-02   8.51624086e-03  -3.50822322e-03
#    -1.45231232e-01  -1.77630167e-02  -3.28622386e-02  -1.24721462e-02
#     5.83205931e-03   4.10841629e-02]
#  [ -9.55965891e-02   3.77929322e-02  -7.89129362e-02   4.62176539e-02
#     5.53556569e-02  -2.48578236e-01   3.48295681e-02  -3.35235223e-02
#     2.30774842e-02   1.29625082e-01]
#  [ -2.05161944e-01   3.55652049e-02   9.44591388e-02   1.11584313e-01
#     1.07357047e-01   9.24579741e-04   1.12420663e-01   1.21570192e-01
#    -9.58700553e-02   4.27810326e-02]
#  [  2.86554173e-02  -6.73355768e-04   1.21041566e-01  -3.24577838e-02
#    -3.93289030e-02   2.73334906e-02   1.58230871e-01  -1.01528399e-01
#     6.68646768e-02   1.10140806e-02]
#  [  1.20664135e-01   7.78921694e-02  -1.80068240e-01   1.38228759e-01
#     3.93839218e-02   3.21857296e-02  -2.32525840e-01  -1.40361786e-01
#     2.96439719e-03   2.27519125e-02]
#  [ -3.18560447e-03   8.95010028e-03   1.49772719e-01   7.36410841e-02
#    -2.45059449e-02   6.28870819e-03  -8.29831988e-04  -3.20484862e-02
#    -6.91324472e-02   8.74658290e-05]]
