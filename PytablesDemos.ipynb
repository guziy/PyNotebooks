# %%
import tables as tb
import numpy as np
from datetime import datetime
import time

# %%
###generate the date to field dictionary
from datetime import datetime, timedelta
def generate_date_to_field_dict():
    t0 = datetime.now()
    res = []
    for i in range(400):
        t = t0 + timedelta(days = 1) * i
        res.append( (t.year, t.month, t.day, t.hour, t.minute, t.second, time.mktime(t.timetuple()) , np.random.randn(10,10)) )
    return res
    
data = generate_date_to_field_dict()

# %%
if h5file.isopen: h5file.close()

print h5file.isopen

h5file = tb.openFile("tutorial1.h5", mode = "w", title = "Test file")
#h5file.removeNode("year_2013")
#h5file.removeNode("year_2014")



##create groups for different years
#for d, v in data.iteritems():
#    yearGroupName = d.strftime("year_%Y") 
#    if not yearGroupName in h5file.root:
#        h5file.createGroup("/", d.strftime("year_%Y"))
    

    
#delete nodes created for each year
for year in (2013, 2014):
    nodePath = "/" + "year-{0}".format(year)
    if nodePath in h5file:
        h5file.removeNode(nodePath)

    nodePath = "/" + "year_{0}".format(year)
    if nodePath in h5file:
        h5file.removeNode(nodePath)
        
#ceate a table  for a variable random and call it random        
print h5file


#when passing pos make sure to use different variables
class RandomTableDescription(tb.IsDescription):
    year = tb.Int32Col()

    month = tb.Int32Col()
    
    day = tb.Int32Col()
    
    hour = tb.Int32Col()
    
    minute = tb.Int32Col()
    
    second = tb.Int32Col()
    
    
    date = tb.Time32Col()
    
    field = tb.Float32Col(shape = data[0][-1].shape)


#create random table if it does not exist yet
if "/random" not in h5file:
    randomTable = h5file.createTable("/", "random", RandomTableDescription)
else:
    randomTable = h5file.getNode("/random")

#randomTable.append(data)    

row = randomTable.row

for rowData in data:
    row["year"] = rowData[0]
    row["month"] = rowData[1]
    row["day"] = rowData[2]
    row["hour"] = rowData[3]
    row["minute"] = rowData[4]
    row["second"] = rowData[5]
    row["date"] = rowData[6]
    row["field"] = rowData[-1]
    row.append()
randomTable.flush()


#print data.items()
print h5file

h5file.close()
    
    
##To see the schema of the created file in command line, do:
#huziy$ ptdump-2.7 -v tutorial1.h5
#/ (RootGroup) 'Test file'
#/random (Table(400,)) ''
#  description := {
#  "day": Int32Col(shape=(), dflt=0, pos=0),
#  "field": Float32Col(shape=(10, 10), dflt=0.0, pos=1),
#  "hour": Int32Col(shape=(), dflt=0, pos=2),
#  "minute": Int32Col(shape=(), dflt=0, pos=3),
#  "month": Int32Col(shape=(), dflt=0, pos=4),
#  "second": Int32Col(shape=(), dflt=0, pos=5),
#  "year": Int32Col(shape=(), dflt=0, pos=6)}
#  byteorder := 'little'
#  chunkshape := (154,)
# Out:
# 0
# tutorial1.h5 (File) 'Test file'
# Last modif.: 'Fri Jun  7 08:33:05 2013'
# Object Tree:
# / (RootGroup) 'Test file'
#
# tutorial1.h5 (File) 'Test file'
# Last modif.: 'Fri Jun  7 08:33:05 2013'
# Object Tree:
# / (RootGroup) 'Test file'
# /random (Table(400,)) ''

# %%
h5file = tb.openFile("tutorial1.h5")

print h5file

randomTable = h5file.getNode("/random")

##selecting by index
for x in randomTable.iterrows(start = 10, stop = 20):
    print x["year"]
print 20 * "==="
##selecting by condition
##calculate summer mean
all_data = []
for row in randomTable.where("(month >= 6) & (month <= 8)"):
    all_data.append(row["field"])
    

print len(all_data)
print np.mean(all_data, axis = 0)
h5file.close()
# Out:
# tutorial1.h5 (File) 'Test file'
# Last modif.: 'Fri Jun  7 08:33:05 2013'
# Object Tree:
# / (RootGroup) 'Test file'
# /random (Table(400,)) ''
#
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# ============================================================
# 127
# [[ 0.12716749 -0.02968115 -0.06706869 -0.00117834  0.09499503  0.00748523
#   -0.21439435  0.10625561 -0.102397   -0.09706819]
#  [-0.02778511  0.03916132 -0.08646721  0.0131039  -0.03922694  0.06519429
#   -0.12594526  0.02675062 -0.0042139   0.05384409]
#  [-0.05497095  0.07756322  0.0230538  -0.11806892  0.09606974  0.11593668
#   -0.07419798 -0.04878316 -0.18065809  0.11539334]
#  [ 0.00892621 -0.05817394  0.00295179 -0.12535594 -0.02877308  0.02039527
#   -0.09963623  0.06095469  0.07047354 -0.06045114]
#  [-0.10452542 -0.01758335 -0.04947668 -0.01939212 -0.08647725 -0.08123978
#    0.0129326   0.01627802  0.11621948  0.007582  ]
#  [-0.11867935  0.15658028  0.05651469  0.07223393  0.07907078  0.01286526
#   -0.09316958  0.0535337  -0.08130002 -0.01245874]
#  [-0.01120561 -0.10067154 -0.0688564   0.00554256 -0.01271424  0.25708073
#    0.03178931 -0.02448882 -0.18807995  0.02145934]
#  [-0.08201694  0.02097246  0.06704072 -0.03947178  0.03802342  0.00722009
#    0.09191811  0.02320686 -0.06374504  0.10588397]
#  [-0.11603745  0.02288266 -0.04900294 -0.15649542  0.01009043  0.12572268
#   -0.0229607  -0.0065873   0.0327387   0.00087022]
#  [-0.08758385 -0.0386352   0.13318779  0.1400239  -0.00366699 -0.10875779
#   -0.03788802  0.22504963 -0.07184694 -0.09509312]]
