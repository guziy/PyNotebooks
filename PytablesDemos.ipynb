# %%
import tables as tb
import numpy as np
from datetime import datetime
import time

# %%
###generate the date to field dictionary
from datetime import datetime, timedelta
def generate_date_to_field_dict():
    t0 = datetime.now()
    res = []
    for i in range(400):
        t = t0 + timedelta(days = 1) * i
        res.append( (t.year, t.month, t.day, t.hour, t.minute, t.second, np.random.randn(10,10)) )
    return res
    
data = generate_date_to_field_dict()

# %%
if h5file.isopen: h5file.close()
    
h5file = tb.openFile("tutorial1.h5", mode = "w", title = "Test file")
#h5file.removeNode("year_2013")
#h5file.removeNode("year_2014")



##create groups for different years
#for d, v in data.iteritems():
#    yearGroupName = d.strftime("year_%Y") 
#    if not yearGroupName in h5file.root:
#        h5file.createGroup("/", d.strftime("year_%Y"))
    

    
#delete nodes created for each year
for year in (2013, 2014):
    nodePath = "/" + "year-{0}".format(year)
    if nodePath in h5file:
        h5file.removeNode(nodePath)

    nodePath = "/" + "year_{0}".format(year)
    if nodePath in h5file:
        h5file.removeNode(nodePath)
        
#ceate a table  for a variable random and call it random        
print h5file


#when passing pos make sure to use different variables
class RandomTableDescription(tb.IsDescription):
    year = tb.Int32Col()

    month = tb.Int32Col()
    
    day = tb.Int32Col()
    
    hour = tb.Int32Col()
    
    minute = tb.Int32Col()
    
    second = tb.Int32Col()
    
    field = tb.Float32Col(shape = data[0][-1].shape)


#create random table if it does not exist yet
if "/random" not in h5file:
    randomTable = h5file.createTable("/", "random", RandomTableDescription)
else:
    randomTable = h5file.getNode("/random")

#randomTable.append(data)    

row = randomTable.row

for rowData in data:
    row["year"] = rowData[0]
    row["month"] = rowData[1]
    row["day"] = rowData[2]
    row["hour"] = rowData[3]
    row["minute"] = rowData[4]
    row["second"] = rowData[5]
    row["field"] = rowData[-1]
    row.append()
randomTable.flush()


#print data.items()
print h5file

h5file.close()
    
    
##To see the schema of the created file in command line, do:
#huziy$ ptdump-2.7 -v tutorial1.h5
#/ (RootGroup) 'Test file'
#/random (Table(400,)) ''
#  description := {
#  "day": Int32Col(shape=(), dflt=0, pos=0),
#  "field": Float32Col(shape=(10, 10), dflt=0.0, pos=1),
#  "hour": Int32Col(shape=(), dflt=0, pos=2),
#  "minute": Int32Col(shape=(), dflt=0, pos=3),
#  "month": Int32Col(shape=(), dflt=0, pos=4),
#  "second": Int32Col(shape=(), dflt=0, pos=5),
#  "year": Int32Col(shape=(), dflt=0, pos=6)}
#  byteorder := 'little'
#  chunkshape := (154,)
# Out:
# tutorial1.h5 (File) 'Test file'
# Last modif.: 'Thu Jun  6 16:49:07 2013'
# Object Tree:
# / (RootGroup) 'Test file'
#
# tutorial1.h5 (File) 'Test file'
# Last modif.: 'Thu Jun  6 16:49:07 2013'
# Object Tree:
# / (RootGroup) 'Test file'
# /random (Table(400,)) ''

# %%
h5file = tb.openFile("tutorial1.h5")

print h5file

randomTable = h5file.getNode("/random")

##selecting by index
for x in randomTable.iterrows(start = 10, stop = 20):
    print x["year"]
print 20 * "==="
##selecting by condition
##calculate summer mean
all_data = []
for row in randomTable.where("(month >= 6) & (month <= 8)"):
    all_data.append(row["field"])
    

print len(all_data)
print np.mean(all_data, axis = 0)
# Out:
# tutorial1.h5 (File) 'Test file'
# Last modif.: 'Thu Jun  6 16:49:07 2013'
# Object Tree:
# / (RootGroup) 'Test file'
# /random (Table(400,)) ''
#
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# 2013
# ============================================================
# 127
# [[  2.17731725e-02   6.47591203e-02   3.17628719e-02   2.80316416e-02
#     1.37308761e-01   2.91719213e-02  -1.44116012e-02  -5.35672903e-02
#    -9.20841694e-02   1.89093854e-02]
#  [ -1.33217335e-01   8.67623389e-02  -3.60835865e-02  -1.37941455e-02
#     4.79299687e-02  -9.60167646e-02   2.32582297e-02   5.41496426e-02
#     1.41893461e-01   1.03789486e-01]
#  [  8.09496418e-02  -2.94772238e-02  -7.51032904e-02  -3.75932045e-02
#     9.24098939e-02   9.25686583e-02  -8.86261240e-02  -2.29777783e-01
#     2.05113329e-02   9.74632055e-03]
#  [  9.07244608e-02  -7.43700191e-02   7.36979991e-02  -8.45069124e-04
#     9.95475799e-02  -8.29683803e-03  -3.99301201e-02   6.65926412e-02
#    -8.95649269e-02  -3.16312388e-02]
#  [  6.93679508e-03   6.76259297e-05   9.27641839e-02   5.61683811e-02
#     2.11893290e-01   8.49864334e-02   5.49508706e-02   4.94051818e-03
#    -1.58135016e-02  -3.36572006e-02]
#  [ -1.72956511e-01  -7.20250905e-02  -4.47532050e-02   3.34306359e-02
#    -3.03992233e-03   8.40581581e-02   5.36614470e-02   7.18916720e-03
#     6.02189712e-02   3.39111760e-02]
#  [  2.19715405e-02   2.05770950e-03   2.90919524e-02   1.08094446e-01
#    -1.25988096e-01  -1.13703534e-01  -1.27912387e-01  -2.90139280e-02
#    -4.06505987e-02   4.82565984e-02]
#  [ -2.42099725e-02   1.54213328e-02  -1.28090587e-02   4.31784950e-02
#    -6.53980672e-02  -1.03328332e-01   2.94032954e-02   1.78229704e-01
#     1.68677405e-01  -9.90827903e-02]
#  [  1.13538116e-01   1.09320216e-01   1.35019064e-01   2.69220807e-02
#     1.74163699e-01  -1.57421246e-01  -9.37965214e-02  -1.03243580e-02
#     1.07517965e-01   1.37604224e-02]
#  [  1.02117866e-01  -4.45630327e-02  -5.84777966e-02  -1.67624161e-01
#     1.01585165e-01   6.32435605e-02  -1.29243746e-01  -1.46591216e-02
#     2.33808644e-02  -9.57631692e-02]]
