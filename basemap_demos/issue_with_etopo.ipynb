# %%
from mpl_toolkits.basemap import Basemap
m = Basemap(llcrnrlon=-124.7, llcrnrlat=-0.6,
                    urcrnrlon=-64.5, urcrnrlat=59.3,
                    rsphere=(6378137.00,6356752.3142),projection='merc')
m.etopo()
m.drawcoastlines()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-4-93a33982866a> in <module>()
#       3                     urcrnrlon=-64.5, urcrnrlat=59.3,
#       4                     rsphere=(6378137.00,6356752.3142),projection='merc')
# ----> 5 m.etopo()
#       6 m.drawcoastlines()
#
# /home/san/Python/virtual_envs/py2.7-default/local/lib/python2.7/site-packages/mpl_toolkits/basemap/__init__.pyc in etopo(self, ax, scale, **kwargs)
#    4015             return self.warpimage(image='etopo',ax=ax,scale=scale,**kwargs)
#    4016         else:
# -> 4017             return self.warpimage(image='etopo',scale=scale,**kwargs)
#    4018
#    4019     def warpimage(self,image="bluemarble",scale=None,**kwargs):
#
# /home/san/Python/virtual_envs/py2.7-default/local/lib/python2.7/site-packages/mpl_toolkits/basemap/__init__.pyc in warpimage(self, image, scale, **kwargs)
#    4091                 # orientation of arrays returned by pil_to_array
#    4092                 # changed (https://github.com/matplotlib/matplotlib/pull/616)
# -> 4093                 self._bm_rgba = pil_to_array(pilImage)[::-1,:]
#    4094             else:
#    4095                 self._bm_rgba = pil_to_array(pilImage)
#
# /home/san/Python/virtual_envs/py2.7-default/local/lib/python2.7/site-packages/matplotlib/image.pyc in pil_to_array(pilImage)
#    1326         #return MxNx3 RGB array
#    1327         im = pilImage  # no need to RGB images
# -> 1328         x = toarray(im)
#    1329         x.shape = im.size[1], im.size[0], 3
#    1330         return x
#
# /home/san/Python/virtual_envs/py2.7-default/local/lib/python2.7/site-packages/matplotlib/image.pyc in toarray(im, dtype)
#    1311     def toarray(im, dtype=np.uint8):
#    1312         """Teturn a 1D array of dtype."""
# -> 1313         x_str = im.tostring('raw', im.mode)
#    1314         x = np.fromstring(x_str, dtype)
#    1315         return x
#
# /home/san/Python/virtual_envs/py2.7-default/local/lib/python2.7/site-packages/PIL/Image.pyc in tostring(self, encoder_name, *args)
#     530
#     531         :param encoder_name: What encoder to use.  The default is to
# --> 532                              use the standard "raw" encoder.
#     533         :param args: Extra arguments to the encoder.
#     534         :rtype: A bytes object.
#
# /home/san/Python/virtual_envs/py2.7-default/local/lib/python2.7/site-packages/PIL/ImageFile.pyc in load(self)
#     187             except AttributeError:
#     188                 prefix = b""
# --> 189
#     190             for d, e, o, a in self.tile:
#     191                 d = Image._getdecoder(self.mode, d, a, self.decoderconfig)
#
# /home/san/Python/virtual_envs/py2.7-default/local/lib/python2.7/site-packages/PIL/Image.pyc in _getdecoder(mode, decoder_name, args, extra)
#     383     elif not isinstance(args, tuple):
#     384         args = (args,)
# --> 385
#     386     try:
#     387         # get decoder
#
# IOError: decoder jpeg not available
