# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %%
b = Basemap(projection="ortho", lat_0=90, lon_0=-100)
b.drawcoastlines(linewidth=0.5)
b.etopo()
