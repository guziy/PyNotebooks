# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from PIL import Image
import urllib
m = Basemap(projection='cyl',llcrnrlon=-90,llcrnrlat=30,urcrnrlon=-60,urcrnrlat=60, epsg="4326")

m.arcgisimage(verbose=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/Python/anaconda3/lib/python3.7/site-packages/numpy/core/__init__.py in <module>
#      15 try:
# ---> 16     from . import multiarray
#      17 except ImportError as exc:
#
# ImportError: libmkl_rt.so: cannot open shared object file: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-18c43d1bdc96> in <module>
# ----> 1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2
#       3 import numpy as np
#       4 import matplotlib.pyplot as plt
#       5 from mpl_toolkits.basemap import Basemap
#
# ~/Python/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
# ...

# %%
# bm_url = "http://server.arcgisonline.com/ArcGIS/rest/services/ESRI_Imagery_World_2D/MapServer/export?bbox=-90.0,29.999999999999996,-59.99999999999999,59.99999999999999&bboxSR=4326&imageSR=4326&size=400,400&dpi=96&format=png32&f=image"


import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from PIL import Image
import urllib
m = Basemap(projection='cyl',llcrnrlon=-90,llcrnrlat=30,urcrnrlon=-60,urcrnrlat=60, epsg="4326")

bm_url = f"http://server.arcgisonline.com/ArcGIS/rest/services/ESRI_Imagery_World_2D/MapServer/export?bbox={m.llcrnrlon},{m.llcrnrlat},{m.urcrnrlon},{m.urcrnrlat}&bboxSR=4326&imageSR=4326&size=400,400&dpi=96&format=png32&transparent=true&f=image"

im = Image.open(urllib.request.urlopen(bm_url))

m.imshow(im, origin="upper")
plt.show()

# %%
import pyproj
p = pyproj.Proj(init="epsg:%s" % m.epsg, preserve_units=True)

p(m.llcrnrlon, m.llcrnrlat)
# Out:
# /home/huziy/Python/anaconda3/envs/py373/lib/python3.7/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# /home/huziy/Python/anaconda3/envs/py373/lib/python3.7/site-packages/pyproj/crs/crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# (-90.0, 29.999999999999996)

# %%
from matplotlib.image import imread

# %%
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-8-d42d9fd6086b> in <module>
# ----> 1 x = imread(bm_url)
#
# ~/Python/anaconda3/envs/py373/lib/python3.7/site-packages/matplotlib/image.py in imread(fname, format)
#    1473             from urllib import request
#    1474             with urllib.request.urlopen(fname) as response:
# -> 1475                 return imread(response, format=ext)
#    1476     with img_open(fname) as image:
#    1477         return (_pil_png_to_float_array(image)
#
# ~/Python/anaconda3/envs/py373/lib/python3.7/site-packages/matplotlib/image.py in imread(fname, format)
#    1474             with urllib.request.urlopen(fname) as response:
#    1475                 return imread(response, format=ext)
# -> 1476     with img_open(fname) as image:
#    1477         return (_pil_png_to_float_array(image)
# ...
